# %% [markdown]
# <a href="https://colab.research.google.com/github/pks98/Pracfiles/blob/main/HandlingMixedData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('titanic.csv')

# %%
df
# Out:
#     Cabin            Ticket number  Survived
# 0     NaN         A/5 21171      5         0
# 1     C85          PC 17599      3         1
# 2     NaN  STON/O2. 3101282      6         1
# 3    C123            113803      3         1
# 4     NaN            373450      A         0
# ..    ...               ...    ...       ...
# 886   NaN            211536      3         0
# 887   B42            112053      3         1
# 888   NaN        W./C. 6607      1         0
# 889  C148            111369      2         1
# 890   NaN            370376      3         0
#
# [891 rows x 4 columns]

# %% [markdown]
# Seperating numerical and categorical values from the number column

# %%
df['number_numerical']=pd.to_numeric(df['number'],errors='coerce',downcast='integer')

# %%
df.head()
# Out:
#   Cabin            Ticket number  Survived  number_numerical
# 0   NaN         A/5 21171      5         0               5.0
# 1   C85          PC 17599      3         1               3.0
# 2   NaN  STON/O2. 3101282      6         1               6.0
# 3  C123            113803      3         1               3.0
# 4   NaN            373450      A         0               NaN

# %%
df['number_categorical']=np.where(df['number_numerical'].isnull(),df['number'],np.nan)

# %%
df.head()
# Out:
#   Cabin            Ticket number  Survived  number_numerical  \
# 0   NaN         A/5 21171      5         0               5.0
# 1   C85          PC 17599      3         1               3.0
# 2   NaN  STON/O2. 3101282      6         1               6.0
# 3  C123            113803      3         1               3.0
# 4   NaN            373450      A         0               NaN
#
#   number_categorical
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                  A

# %% [markdown]
# Splitting the ctegorical and numbers from the column Cabin

# %%
df['Seat_number']=df['Cabin'].str.extract('(\d+)')

# %%
df.head()
# Out:
#   Cabin            Ticket number  Survived  number_numerical  \
# 0   NaN         A/5 21171      5         0               5.0
# 1   C85          PC 17599      3         1               3.0
# 2   NaN  STON/O2. 3101282      6         1               6.0
# 3  C123            113803      3         1               3.0
# 4   NaN            373450      A         0               NaN
#
#   number_categorical Seat_number
# 0                NaN         NaN
# 1                NaN          85
# 2                NaN         NaN
# 3                NaN         123
# 4                  A         NaN

# %%
df['Cabin_Number']=df['Cabin'].str.extract('(\D+)')

# %%
df.head()
# Out:
#   Cabin            Ticket number  Survived  number_numerical  \
# 0   NaN         A/5 21171      5         0               5.0
# 1   C85          PC 17599      3         1               3.0
# 2   NaN  STON/O2. 3101282      6         1               6.0
# 3  C123            113803      3         1               3.0
# 4   NaN            373450      A         0               NaN
#
#   number_categorical Seat_number Cabin_Number
# 0                NaN         NaN          NaN
# 1                NaN          85            C
# 2                NaN         NaN          NaN
# 3                NaN         123            C
# 4                  A         NaN          NaN

# %%
df["Ticket_cat"]=df['Ticket'].apply(lambda x:x.split()[0])

# %%
df['Ticket_cat']
# Out:
# 0           A/5
# 1            PC
# 2      STON/O2.
# 3        113803
# 4        373450
#          ...
# 886      211536
# 887      112053
# 888       W./C.
# 889      111369
# 890      370376
# Name: Ticket_cat, Length: 891, dtype: object

# %%
df['Ticket_cat']=np.where(df['Ticket_cat'].str.isdigit(),np.nan,df['Ticket_cat'])

# %%
df['Ticket_cat']
# Out:
# 0           A/5
# 1            PC
# 2      STON/O2.
# 3           NaN
# 4           NaN
#          ...
# 886         NaN
# 887         NaN
# 888       W./C.
# 889         NaN
# 890         NaN
# Name: Ticket_cat, Length: 891, dtype: object

# %%
df['Ticket_number']=df['Ticket'].apply(lambda x:x.split()[-1])

# %%
df['Ticket_number']
# Out:
# 0        21171
# 1        17599
# 2      3101282
# 3       113803
# 4       373450
#         ...
# 886     211536
# 887     112053
# 888       6607
# 889     111369
# 890     370376
# Name: Ticket_number, Length: 891, dtype: object

# %%
df['Ticket_number']=pd.to_numeric(df['Ticket_number'],errors='coerce',downcast='integer')

# %%
df.head()
# Out:
#   Cabin            Ticket number  Survived  number_numerical  \
# 0   NaN         A/5 21171      5         0               5.0
# 1   C85          PC 17599      3         1               3.0
# 2   NaN  STON/O2. 3101282      6         1               6.0
# 3  C123            113803      3         1               3.0
# 4   NaN            373450      A         0               NaN
#
#   number_categorical Seat_number Cabin_Number Ticket_cat  Ticket_number
# 0                NaN         NaN          NaN        A/5        21171.0
# 1                NaN          85            C         PC        17599.0
# 2                NaN         NaN          NaN   STON/O2.      3101282.0
# 3                NaN         123            C        NaN       113803.0
# 4                  A         NaN          NaN        NaN       373450.0
